# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../Data/萧山房源.csv')

# %%
df.head()
# Out:
#                        标题                              介绍       小区  价格（万元）  \
# 0        创世纪高楼层满两年带车位看房方便  地铁2号线盈丰路站，双泳池 开发商精装修 地暖空调 新风系统  融信保利创世纪   760.0
# 1         公寓，民水电天然气地铁口50米                 公寓，民水电天然气地铁口50米   德意中兴广场   225.0
# 2         满二，三开间朝南无遮挡，三阳台             满二，房屋空置，看房方便。朝南三阳台。    保利霞飞郡   399.0
# 3  地铁口，次新房，业主诚售，毛坯房，看房方便，  地铁口，次新房，业主诚售，毛坯房，看房方便，楼层适中采光充足     开元广场   410.0
# 4            北辰国颂府 4室2厅 南                            暂无数据    北辰国颂府   899.0
#
#    平米单价（元）  建筑面积（平米）  套内面积（平米） 大区域    小区域        户型  ... 建筑类型  建筑结构 建造时间  \
# 0    85346     89.05       NaN  萧山  钱江世纪城  3室2厅1厨2卫  ...   板楼  钢混结构  NaN
# 1    17340    129.76       NaN  萧山  萧山新城区  3室2厅1厨2卫  ...   板楼  钢混结构  NaN
# 2    47620     83.79     66.51  萧山  萧山新城区  3室2厅1厨1卫  ...   塔楼  钢混结构  NaN
# 3    31144    131.65       NaN  萧山   南部卧城  3室2厅1厨2卫  ...   板楼  钢混结构  NaN
# 4    52132    172.45    133.76  萧山   萧山市区  4室2厅1厨2卫  ...   板楼  钢混结构  NaN
#
#    房屋用途        挂牌时间      上次交易时间  房屋年限 产权所属 配备电梯  梯户比例
# ...

# %%
df1=df.drop_duplicates()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2711 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   标题        2711 non-null   object
#  1   介绍        2711 non-null   object
#  2   小区        2711 non-null   object
#  3   价格（万元）    2679 non-null   float64
#  4   平米单价（元）   2711 non-null   int64
#  5   建筑面积（平米）  2711 non-null   float64
#  6   套内面积（平米）  1116 non-null   float64
#  7   大区域       2711 non-null   object
#  8   小区域       2711 non-null   object
#  9   户型        2711 non-null   object
#  10  朝向        2711 non-null   object
#  11  所在楼层      2711 non-null   object
#  12  装修情况      2711 non-null   object
#  13  户型结构      2711 non-null   object
#  14  建筑类型      2711 non-null   object
#  15  建筑结构      2711 non-null   object
#  16  建造时间      0 non-null      float64
#  17  房屋用途      2711 non-null   object
#  18  挂牌时间      2711 non-null   object
#  19  上次交易时间    2711 non-null   object
# ...

# %%
df1.shape
# Out:
# (2711, 24)

# %%
data=df1.drop(['标题','介绍','套内面积（平米）','大区域',''],axis=1)
