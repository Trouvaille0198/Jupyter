# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
data=pd.read_csv('../Data/players_info.csv')
data.head(10)
# Out:
#                                 Name                 Club  \
# 0                       Lionel Messi         FC Barcelona
# 1       C. Ronaldo dos Santos Aveiro      Piemonte Calcio
# 2         Neymar da Silva Santos Jr.  Paris Saint-Germain
# 3                    Kevin De Bruyne      Manchester City
# 4                 Robert Lewandowski       Bayern München
# 5                         Sadio Mané            Liverpool
# 6                      Mohamed Salah            Liverpool
# 7                      Kylian Mbappé  Paris Saint-Germain
# 8                    Virgil van Dijk            Liverpool
# 9  Carlos Henrique Venancio Casimiro          Real Madrid
#
#                    League     Nation  Age  Height Position  Rating  PACE  \
# 0  Spain Primera División  Argentina   33     170       RW      93  85.0
# 1           Italy Serie A   Portugal   35     187       ST      92  89.0
# 2          France Ligue 1     Brazil   28     175       LW      91  91.0
# ...

# %%
data.duplicated('Name').sum()
data=data.drop_duplicates()

# %%
sns.displot(x='Age',data=data[:800],kde=True)

# %%
sns.displot(x='Height',data=data[:2000],kde=True)

# %%
data[:100]['Nation'].describe()
# Out:
# count       100
# unique       27
# top       Spain
# freq         14
# Name: Nation, dtype: object

# %%
sns.catplot(x='Position',data=data[:200],kind='count')

# %%
sns.catplot(x="Rating", y="Position",kind='box', data=data[:200])

# %%
import pandas_profiling as pp
profile = pp.ProfileReport(data[:500])
profile.to_file("output_file.html")
# Out:
# c:\environment\python39\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
pd.set_option('display.max_rows',1000)

# %%
sns.pairplot(data)

# %%
sns.pairplot(data[:2000])

# %%
data2=data[:2000].query('Position=="CB" or Position=="CDM" or Position=="RB" or Position=="LB" or Position=="CAM"  ')
sns.jointplot(y="DEFENCE", x="DRIBBLING", data=data2,hue='Position')

# %%
sns.jointplot(x="DEFENCE", y="PHYSICAL", data=data[:2000],hue='Position')

# %%
data3=data[:2000].query('Position=="CB" or Position=="ST"   ')
sns.jointplot(x="DEFENCE", y="PHYSICAL", data=data3,hue='Position')

# %%
sns.jointplot(y="SHOOTING", x="PASSING", data=data[:2000],hue='Position')
