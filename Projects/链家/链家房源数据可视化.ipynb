# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
mpl.rc("font", family='MicroSoft YaHei', weight='bold')

plt.figure(figsize=(15, 10))

# %%
data=pd.read_csv('../../Data/萧山房源数据整理版.csv')

# %%
data.head(3)
# Out:
#         小区  价格（万元）  平米单价（元）  建筑面积（平米）    小区域 朝向 装修情况 户型结构 建筑类型  建筑结构  ...  \
# 0  融信保利创世纪   760.0    85346     89.05  钱江世纪城  南   精装   平层   板楼  钢混结构  ...
# 1   德意中兴广场   225.0    17340    129.76  萧山新城区  南   精装   平层   板楼  钢混结构  ...
# 2    保利霞飞郡   399.0    47620     83.79  萧山新城区  南   精装   平层   塔楼  钢混结构  ...
#
#   产权所属 配备电梯        挂牌时间/秒      上次交易时间/秒  楼层高度  总楼层数 卧室数  客厅数  厨房数  厕所数
# 0   共有    有  1.610554e+09  1.539187e+09     中    32   3    2    1    2
# 1  非共有    有  1.599926e+09  1.216224e+09     中    30   3    2    1    2
# 2   共有    有  1.610208e+09  1.473437e+09     低    26   3    2    1    1
#
# [3 rows x 22 columns]

# %%
data.describe()
# Out:
#             价格（万元）       平米单价（元）     建筑面积（平米）        挂牌时间/秒      上次交易时间/秒  \
# count  2678.000000   2678.000000  2678.000000  2.678000e+03  2.678000e+03
# mean    358.061240  31264.795743   113.769414  1.590717e+09  1.443096e+09
# std     217.714867  11749.972674    47.561136  2.002937e+07  1.614046e+08
# min      39.000000   7959.000000    20.500000  1.494778e+09  7.470720e+08
# 25%     230.000000  24429.000000    87.195000  1.585843e+09  1.353578e+09
# 50%     310.000000  28610.500000   108.140000  1.596816e+09  1.502251e+09
# 75%     425.000000  35598.000000   137.422500  1.605110e+09  1.565626e+09
# max    2100.000000  99877.000000   427.440000  1.611936e+09  1.640362e+09
#
#               总楼层数          卧室数          客厅数          厨房数          厕所数
# count  2678.000000  2678.000000  2678.000000  2678.000000  2678.000000
# mean     18.346527     3.103809     1.755041     1.010456     1.800224
# std      10.225044     0.961559     0.474728     0.138980     0.642220
# ...

# %%
sns.displot(x='价格（万元）',data=data[data['价格（万元）']<1300],kde=True)

# %%
sns.displot(x='建筑面积（平米）',data=data[(data['建筑面积（平米）']>30) & (data['建筑面积（平米）']<250)],kde=True)

# %%
sns.displot(x='总楼层数',data=data,kde=True)

# %%
sns.catplot(x='装修情况',data=data,kind='count')

# %%
sns.catplot(x='户型结构',data=data,kind='count')

# %%
sns.catplot(x='建筑类型',data=data,kind='count')

# %%
sns.catplot(x='建筑结构',data=data,kind='count')

# %%
sns.catplot(x='房屋用途',data=data,kind='count')

# %%
g = sns.catplot(x='小区域',data=data,kind='count')
g.fig.set_size_inches(15,10)

# %%
sns.catplot(x='房屋年限',data=data,kind='count')

# %%
sns.catplot(x='产权所属',data=data,kind='count')

# %%
sns.catplot(x='配备电梯',data=data,kind='count')

# %%
sns.catplot(x='楼层高度',data=data,kind='count')

# %%
sns.jointplot(x="价格（万元）", y="建筑面积（平米）", data=data,hue='房屋用途')

# %%
sns.displot(x="价格（万元）",data=data,kind='kde',hue='装修情况')
# Out:
# C:\environment\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
gg = sns.pairplot(data=data)

# %%
# gg.savefig('../Data/gg.png')
